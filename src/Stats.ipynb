# %% [markdown]
# #### Descriptive Statistics on Diabetic Patients at least 21 years old of Pima Indian heritage: Data provided by National Institute of Diabetes and Digestive and Kidney Diseases.

# %% [markdown]
# I first wanted to do a statistical analysis of the data on three predictor variables.  I investigated three different medical predictors of diabetes: Glucose, Insulin, BMI. In effort to understand if a patient had diabetes or not (1- had diabetes, 0 - does not have diabetes).

# %%
import lib
import pandas as pd

# %%
# importing functions from lib.py and then using them to display visualization of data
data = pd.read_csv("../data/diabetes.csv")
column_g = "Glucose"
column_i = "Insulin"
column_b = "BMI"

print("Column Name: ", column_g)
print("Maximum: ", lib.maximum(data, column_g))
print("Minimum: ", lib.minimum(data, column_g))
print("Mean: ", lib.get_mean(data, column_g))
print("Median: ", lib.get_median(data, column_g))
print("Standard Deviation: ", lib.get_std_dev(data, column_g))
print("\n")
print("Column Name: ", column_i)
print("Maximum: ", lib.maximum(data, column_i))
print("Minimum: ", lib.minimum(data, column_i))
print("Mean: ", lib.get_mean(data, column_i))
print("Median: ", lib.get_median(data, column_i))
print("Standard Deviation: ", lib.get_std_dev(data, column_i))
print("\n")
print("Column Name: ", column_b)
print("Maximum: ", lib.maximum(data, column_b))
print("Minimum: ", lib.minimum(data, column_b))
print("Mean: ", lib.get_mean(data, column_b))
print("Median: ", lib.get_median(data, column_b))
print("Standard Deviation: ", lib.get_std_dev(data, column_b))
# Out:
# Column Name:  Glucose
# Maximum:  199
# Minimum:  0
# Mean:  120.89453125
# Median:  117.0
# Standard Deviation:  31.97261819513622
#
#
# Column Name:  Insulin
# Maximum:  846
# Minimum:  0
# Mean:  79.79947916666667
# Median:  30.5
# Standard Deviation:  115.24400235133817
#
#
# Column Name:  BMI
# Maximum:  67.1
# Minimum:  0.0
# Mean:  31.992578124999998
# Median:  32.0
# Standard Deviation:  7.884160320375446

# %% [markdown]
# Now, I want to visualize these descriptive statistics in three different ways. First I am going to display a countplot which shows each the counts of each data type used in this particular dataset. I want to show a bar plot that showed based the range of which specific glucose, insulin, BMI values results in a accurate diabetes diagnosis. Finally, I wanted to tabulate the data in a clean table to show how each descriptive stats compares for each of the three predictor variables.

# %%
# Visualizing the Descriptive Statistics
lib.visualize_dataset(data, jupyter=True)
lib.display_statistics(data, jupyter=True)
# Out:
# Visualization of Diabetes Dataset
